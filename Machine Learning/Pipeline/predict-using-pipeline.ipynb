# %%
import pickle
import pandas as pd

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
test_input2 = pd.DataFrame([[2, 'male', 31.0, 0, 0, 10.5, 'S']], columns=[
    'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'
])

# %%
pipe.predict(test_input2)
# Out:
# array([0])
