# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
X, y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature': X[:,0], 'feature2': X[:,1], 'target': y})

# %%
df.head()
# Out:
#     feature  feature2      target
# 0  0.279621  1.368098   48.281275
# 1 -0.109376  0.928266   66.187495
# 2 -0.908472  1.257172   73.967251
# 3  0.003557  0.960408  101.445758
# 4 -0.064483  0.384903    8.417523

# %%
fig = px.scatter_3d(df, x="feature", y="feature2", z="target", color="target")
fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE", mean_absolute_error(y_test, y_pred))
print("MSE", mean_squared_error(y_test, y_pred))
print("R2", r2_score(y_test, y_pred))
# Out:
# MAE 36.68267245430445
# MSE 2406.9205253910422
# R2 0.8217587622257669

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)

xGrid, yGrid = np.meshgrid(y, x)

final = np.vstack((xGrid.ravel().reshape(1,100), yGrid.ravel().reshape(1,100))).T

# %%
z_final = lr.predict(final).reshape(10, 10)

z = z_final

fig = px.scatter_3d(df, x='feature', y='feature2', z='target')

fig.add_trace(go.Surface(x=x, y=y, z=z))

fig.show()

# %%
lr.coef_
# Out:
# array([32.30625085, 91.47791358])

# %%
lr.intercept_
# Out:
# np.float64(2.6729681716546825)
