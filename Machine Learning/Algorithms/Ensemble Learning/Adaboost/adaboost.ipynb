# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from mlxtend.plotting import plot_decision_regions

# %%
df = pd.DataFrame()

# %%
df['X1'] = [1,2,3,4,5,6,6,7,9,9]
df['X2'] = [5,3,6,8,1,9,5,8,9,2]
df['label'] = [1,1,0,1,0,1,0,1,0,0]

# %%
df
# Out:
#    X1  X2  label
# 0   1   5      1
# 1   2   3      1
# 2   3   6      0
# 3   4   8      1
# 4   5   1      0
# 5   6   9      1
# 6   6   5      0
# 7   7   8      1
# 8   9   9      0
# 9   9   2      0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x=df['X1'],y=df['X2'],hue=df['label'])
plt.grid(False)

# %%
df['weights'] = 1/df.shape[0]

# %%
df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 4   5   1      0      0.1
# 5   6   9      1      0.1
# 6   6   5      0      0.1
# 7   7   8      1      0.1
# 8   9   9      0      0.1
# 9   9   2      0      0.1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt1 = DecisionTreeClassifier(max_depth=1)

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,2].values

# %%
# Step 2 - Train 1st model
dt1.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 2.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X, y, clf = dt1, legend=2)
# Out:
# <Axes: >

# %%
df['y_pred'] = dt1.predict(X)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred
# 0   1   5      1      0.1       1
# 1   2   3      1      0.1       1
# 2   3   6      0      0.1       1
# 3   4   8      1      0.1       1
# 4   5   1      0      0.1       0
# 5   6   9      1      0.1       1
# 6   6   5      0      0.1       1
# 7   7   8      1      0.1       1
# 8   9   9      0      0.1       1
# 9   9   2      0      0.1       0

# %%
def calculate_model_weight(error):
    return 0.5 * np.log((1 - error) / (error + 0.0000001))

# %%
# Step 3 - calculate the model weight
alpha1 = calculate_model_weight(0.3)
alpha1
# Out:
# np.float64(0.42364893019360184)

# %%
# Step 4 - Update weight
def update_row_weights(row, alpha = 0.423):
    if row['label'] == row['y_pred']:
        return row['weights'] * np.exp(-alpha)
    else:
        return row['weights'] * np.exp(alpha)

# %%
df['updated_weights'] = df.apply(update_row_weights, axis = 1)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 0   1   5      1      0.1       1         0.065508
# 1   2   3      1      0.1       1         0.065508
# 2   3   6      0      0.1       1         0.152653
# 3   4   8      1      0.1       1         0.065508
# 4   5   1      0      0.1       0         0.065508
# 5   6   9      1      0.1       1         0.065508
# 6   6   5      0      0.1       1         0.152653
# 7   7   8      1      0.1       1         0.065508
# 8   9   9      0      0.1       1         0.152653
# 9   9   2      0      0.1       0         0.065508

# %%
df['updated_weights'].sum()
# Out:
# np.float64(0.9165153319682015)

# %%
df['normalized_weights'] = df['updated_weights'] / df['updated_weights'].sum()

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights
# 0   1   5      1      0.1       1         0.065508            0.071475
# 1   2   3      1      0.1       1         0.065508            0.071475
# 2   3   6      0      0.1       1         0.152653            0.166559
# 3   4   8      1      0.1       1         0.065508            0.071475
# 4   5   1      0      0.1       0         0.065508            0.071475
# 5   6   9      1      0.1       1         0.065508            0.071475
# 6   6   5      0      0.1       1         0.152653            0.166559
# 7   7   8      1      0.1       1         0.065508            0.071475
# 8   9   9      0      0.1       1         0.152653            0.166559
# 9   9   2      0      0.1       0         0.065508            0.071475

# %%
df['normalized_weights'].sum()
# Out:
# np.float64(1.0)

# %%
df['cumsum_upper'] = np.cumsum(df['normalized_weights'])

# %%
df['cumsum_lower'] = df['cumsum_upper'] - df['normalized_weights']

# %%
df[['X1', 'X2', 'label', 'weights', 'y_pred', 'updated_weights', 'cumsum_lower', 'cumsum_upper']]
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  cumsum_lower  cumsum_upper
# 0   1   5      1      0.1       1         0.065508      0.000000      0.071475
# 1   2   3      1      0.1       1         0.065508      0.071475      0.142950
# 2   3   6      0      0.1       1         0.152653      0.142950      0.309508
# 3   4   8      1      0.1       1         0.065508      0.309508      0.380983
# 4   5   1      0      0.1       0         0.065508      0.380983      0.452458
# 5   6   9      1      0.1       1         0.065508      0.452458      0.523933
# 6   6   5      0      0.1       1         0.152653      0.523933      0.690492
# 7   7   8      1      0.1       1         0.065508      0.690492      0.761967
# 8   9   9      0      0.1       1         0.152653      0.761967      0.928525
# 9   9   2      0      0.1       0         0.065508      0.928525      1.000000

# %%
def create_new_dataset(df):
    indices = []
    for i in range(df.shape[0]):
        a = np.random.random()
        for index, row in df.iterrows():
            if row['cumsum_upper'] > a and a > row['cumsum_lower']:
                indices.append(index)
    return indices

# %%
index_value = create_new_dataset(df)

# %%
index_value
# Out:
# [2, 3, 4, 7, 6, 2, 8, 2, 2, 8]

# %%
second_df = df.iloc[index_value, [0, 1, 2, 3]]

# %%
second_df
# Out:
#    X1  X2  label  weights
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 4   5   1      0      0.1
# 7   7   8      1      0.1
# 6   6   5      0      0.1
# 2   3   6      0      0.1
# 8   9   9      0      0.1
# 2   3   6      0      0.1
# 2   3   6      0      0.1
# 8   9   9      0      0.1

# %%
dt2 = DecisionTreeClassifier(max_depth=1)

# %%
X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values

# %%
dt2.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(dt2)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 7.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X, y, clf = dt2, legend=2)
# Out:
# <Axes: >

# %%
second_df['y_pred'] = dt2.predict(X)

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred
# 2   3   6      0      0.1       0
# 3   4   8      1      0.1       0
# 4   5   1      0      0.1       0
# 7   7   8      1      0.1       0
# 6   6   5      0      0.1       0
# 2   3   6      0      0.1       0
# 8   9   9      0      0.1       0
# 2   3   6      0      0.1       0
# 2   3   6      0      0.1       0
# 8   9   9      0      0.1       0

# %%
alpha2 = calculate_model_weight(0)

# %%
alpha2
# Out:
# np.float64(8.05904782547916)

# %%
# Step 4 - Update weight
def update_row_weights(row, alpha = 8.05):
    if row['label'] == row['y_pred']:
        return row['weights'] * np.exp(-alpha)
    else:
        return row['weights'] * np.exp(alpha)

# %%
second_df['updated_weights'] = second_df.apply(update_row_weights, axis = 1)

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights
# 2   3   6      0      0.1       0         0.000032
# 3   4   8      1      0.1       0       313.379497
# 4   5   1      0      0.1       0         0.000032
# 7   7   8      1      0.1       0       313.379497
# 6   6   5      0      0.1       0         0.000032
# 2   3   6      0      0.1       0         0.000032
# 8   9   9      0      0.1       0         0.000032
# 2   3   6      0      0.1       0         0.000032
# 2   3   6      0      0.1       0         0.000032
# 8   9   9      0      0.1       0         0.000032

# %%
second_df['normalized_weights'] = second_df['updated_weights'] / second_df['updated_weights'].sum()

# %%
second_df
# Out:
#    X1  X2  label  weights  y_pred  updated_weights  normalized_weights
# 2   3   6      0      0.1       0         0.000032        5.091300e-08
# 3   4   8      1      0.1       0       313.379497        4.999998e-01
# 4   5   1      0      0.1       0         0.000032        5.091300e-08
# 7   7   8      1      0.1       0       313.379497        4.999998e-01
# 6   6   5      0      0.1       0         0.000032        5.091300e-08
# 2   3   6      0      0.1       0         0.000032        5.091300e-08
# 8   9   9      0      0.1       0         0.000032        5.091300e-08
# 2   3   6      0      0.1       0         0.000032        5.091300e-08
# 2   3   6      0      0.1       0         0.000032        5.091300e-08
# 8   9   9      0      0.1       0         0.000032        5.091300e-08

# %%
second_df['cumsum_upper'] = np.cumsum(second_df['normalized_weights'])

# %%
second_df['cumsum_lower'] = second_df['cumsum_upper'] - second_df['normalized_weights']

# %%
second_df[['X1', 'X2', 'label', 'weights', 'y_pred', 'normalized_weights', 'cumsum_lower', 'cumsum_upper']]
# Out:
#    X1  X2  label  weights  y_pred  normalized_weights  cumsum_lower  \
# 2   3   6      0      0.1       0        5.091300e-08  0.000000e+00
# 3   4   8      1      0.1       0        4.999998e-01  5.091300e-08
# 4   5   1      0      0.1       0        5.091300e-08  4.999998e-01
# 7   7   8      1      0.1       0        4.999998e-01  4.999999e-01
# 6   6   5      0      0.1       0        5.091300e-08  9.999997e-01
# 2   3   6      0      0.1       0        5.091300e-08  9.999997e-01
# 8   9   9      0      0.1       0        5.091300e-08  9.999998e-01
# 2   3   6      0      0.1       0        5.091300e-08  9.999998e-01
# 2   3   6      0      0.1       0        5.091300e-08  9.999999e-01
# 8   9   9      0      0.1       0        5.091300e-08  9.999999e-01
#
#    cumsum_upper
# 2  5.091300e-08
# 3  4.999998e-01
# 4  4.999999e-01
# 7  9.999997e-01
# 6  9.999997e-01
# 2  9.999998e-01
# 8  9.999998e-01
# 2  9.999999e-01
# 2  9.999999e-01
# 8  1.000000e+00

# %%
index_value = create_new_dataset(second_df)

# %%
third_df = second_df.iloc[index_value, [0, 1, 2, 3]]
third_df
# Out:
#    X1  X2  label  weights
# 2   3   6      0      0.1
# 7   7   8      1      0.1
# 7   7   8      1      0.1
# 7   7   8      1      0.1
# 7   7   8      1      0.1
# 2   3   6      0      0.1
# 2   3   6      0      0.1
# 2   3   6      0      0.1
# 7   7   8      1      0.1
# 7   7   8      1      0.1

# %%
dt3 = DecisionTreeClassifier()

# %%
X = second_df.iloc[:,0:2].values
y = second_df.iloc[:,2].values

# %%
dt3.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(dt3)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[1] <= 7.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[0] <= 8.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
plot_decision_regions(X, y, clf = dt3, legend=2)
# Out:
# <Axes: >

# %%
third_df['y_pred'] = dt3.predict(X)

# %%
third_df
# Out:
#    X1  X2  label  weights  y_pred
# 2   3   6      0      0.1       0
# 7   7   8      1      0.1       1
# 7   7   8      1      0.1       0
# 7   7   8      1      0.1       1
# 7   7   8      1      0.1       0
# 2   3   6      0      0.1       0
# 2   3   6      0      0.1       0
# 2   3   6      0      0.1       0
# 7   7   8      1      0.1       0
# 7   7   8      1      0.1       0

# %%
alpha3 = calculate_model_weight(0.4)

# %%
alpha3
# Out:
# np.float64(0.20273242905409775)

# %%
print(alpha1, alpha2, alpha3)
# Out:
# 0.42364893019360184 8.05904782547916 0.20273242905409775

# %% [markdown]
# Prediction

# %%
query = np.array([1, 5]).reshape(1, 2)
dt1.predict(query)
# Out:
# array([1])

# %%
dt2.predict(query)
# Out:
# array([0])

# %%
dt3.predict(query)
# Out:
# array([0])

# %%
alpha1 * 1 + alpha2 * (-1) + alpha3 * (-1)
# Out:
# np.float64(-7.838131324339656)

# %%
np.sign(-7.83)
# Out:
# np.float64(-1.0)
