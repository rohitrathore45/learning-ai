# %%
from sklearn.datasets import fetch_openml
boston = fetch_openml(name="boston", as_frame=True)
# Out:
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\datasets\_openml.py:328: UserWarning: Multiple active versions of the dataset matching the name boston exist. Versions may be fundamentally different, returning version 1. Available versions:
# - version 1, status: active
#   url: https://www.openml.org/search?type=data&id=531
# - version 2, status: active
#   url: https://www.openml.org/search?type=data&id=853
#
#   warn(warning_msg)

# %%
import numpy as np

# %%
X, y = boston.data, boston.target

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
X
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lr = LinearRegression()
svr = SVR()
dt = DecisionTreeRegressor()

# %%
estimators = [("lr", lr), ("dt", dt), ("svr", svr)]

# %%
for estimator in estimators:
    scores = cross_val_score(estimator[1], X, y, cv=10, scoring="r2")
    print(estimator[0], np.round(np.mean(scores), 2))
# Out:
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# lr nan
# dt -0.19
# svr -0.41

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr, X, y, cv=10, scoring="r2")
print(np.round(np.mean(scores), 2))
# Out:
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# nan
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:945: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 166, in __call__
#     score = scorer._score(
#         cached_call, estimator, *args, **routed_params.get(name).score
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 409, in _score
#     y_pred = method_caller(
#         estimator,
#     ...<2 lines>...
#         pos_label=pos_label,
#     )
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_scorer.py", line 96, in _cached_call
#     result, _ = _get_response_values(
#                 ~~~~~~~~~~~~~~~~~~~~^
#         estimator, *args, response_method=response_method, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 697, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_voting.py", line 75, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 311, in predict
#     return self._decision_function(X)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\rohit\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_base.py", line 293, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
